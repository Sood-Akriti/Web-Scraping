# %%
from requests import get
url = 'https://www.goodreads.com/shelf/show/ebooks'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage
# ">
# <head>
#   <title>Ebooks Shelf</title>
#
# <meta content='Books shelved as ebooks: The Hunger Games by Suzanne Collins, Catching Fire by Suzanne Collins, Mockingjay by Suzanne Collins, Divergent by Veronica Roth...' name='description'>
# <meta content='telephone=no' name='format-detection'>
# <link href='https://www.goodreads.com/shelf/show/ebooks' rel='canonical'>
#
#
#
#     <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date()

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
book_containers = html_soup.find_all('div', class_ ="elementList")
print(type(book_containers))
print(len(book_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 54

# %%
# Lists to store the scraped data in
names= []
years = []
ratings = []
avgscores = []
votes = []
author=[]
# Extract data from individual movie container
for container in book_containers:
# If the movie has Metascore, then extract:
    if container.find('div', class_ = 'left') is not None:
        name = container.find('a',class_="bookTitle").text
        names.append(name)
        authors = container.find('a',class_="authorName").text
        author.append(authors)
        votes = container.find('span',class_="greyText smallText").text
        votes=votes.split()
        scores=votes[2]
        avgscores.append(scores)
        rates = votes[4]
        ratings.append(rates)
        year= votes[8] 
        years.append(year)

# %%
import pandas as pd
test_df = pd.DataFrame({'book title': names,
'published': years,
'ratings': ratings,
'avg_score': avgscores,
'author': author
})
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   book title  50 non-null     object
#  1   published   50 non-null     object
#  2   ratings     50 non-null     object
#  3   avg_score   50 non-null     object
#  4   author      50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB
# None
#                                            book title published    ratings  \
# 0             The Hunger Games (The Hunger Games, #1)      2008  7,429,362
# 1                Catching Fire (The Hunger Games, #2)      2009  2,994,522
# 2                   Mockingjay (The Hunger Games, #3)      2010  2,747,377
# 3                           Divergent (Divergent, #1)      2011  3,460,810
# 4                     Pride and Prejudice (Paperback)      1813  3,634,812
# 5                  The Fault in Our Stars (Hardcover)      2012  4,365,980
# 6                           Insurgent (Divergent, #2)      2012  1,345,267
# 7   Harry Potter and the Sorcerer's Stone (Harry P...      1997  8,582,169
# 8             Fifty Shades of Grey (Fifty Shades, #1)      2011  2,276,748
# 9      A Game of Thrones (A Song of Ice and Fire, #1)      1996  2,242,511
# 10                              Gone Girl (Paperback)      2012  2,691,550
# 11      The Handmaid's Tale (The Handmaid's Tale, #1)      1985  1,753,678
# 12         City of Bones (The Mortal Instruments, #1)      2007  1,833,541
# 13             The Picture of Dorian Gray (Paperback)      1890  1,216,053
# 14  A Court of Thorns and Roses (A Court of Thorns...      2015  1,024,654
# 15  Harry Potter and the Chamber of Secrets (Harry...      1998  3,313,526
# 16                  The Selection (The Selection, #1)      2012  1,256,255
# 17                                Dracula (Paperback)      1897  1,092,268
# 18  Harry Potter and the Prisoner of Azkaban (Harr...      1999  3,482,522
# 19  Shadow and Bone (The Shadow and Bone Trilogy, #1)      2012    740,179
# 20              Throne of Glass (Throne of Glass, #1)      2012    853,476
# 21  Harry Potter and the Goblet of Fire (Harry Pot...      2000  3,087,313
# 22                          Allegiant (Divergent, #3)      2013    948,486
# 23                            The Martian (Hardcover)      2011    967,063
# 24                              1984 (Kindle Edition)      1949  3,853,016
# 25  Harry Potter and the Deathly Hallows (Harry Po...      2007  3,267,079
# 26                              Jane Eyre (Paperback)      1847  1,862,472
# 27                         The Book Thief (Hardcover)      2007  2,193,420
# 28                       The Night Circus (Hardcover)      2011    829,987
# 29             Fifty Shades Darker (Fifty Shades, #2)      2011    826,184
# 30  Harry Potter and the Order of the Phoenix (Har...      2003  2,953,213
# 31        The Perks of Being a Wallflower (Paperback)      1999  1,522,596
# 32  The Lightning Thief (Percy Jackson and the Oly...      2005  2,469,146
# 33                       The Great Gatsby (Paperback)      1925  4,481,351
# 34                     We Were Liars (Kindle Edition)      2014    850,189
# 35                  Cinder (The Lunar Chronicles, #1)      2012    816,494
# 36  Harry Potter and the Half-Blood Prince (Harry ...      2005  2,859,744
# 37                  The Girl on the Train (Hardcover)      2015  2,530,105
# 38                          The Deal (Off-Campus, #1)      2015    375,290
# 39                       Ready Player One (Hardcover)      2011  1,024,211
# 40                           Fangirl (Kindle Edition)      2013    685,400
# 41                           Little Women (Paperback)      1868  1,951,883
# 42     A Clash of Kings  (A Song of Ice and Fire, #2)      1998    854,775
# 43  Miss Peregrine's Home for Peculiar Children (M...      2011  1,136,889
# 44                Red, White & Royal Blue (Paperback)      2019    544,162
# 45                         Eleanor & Park (Hardcover)      2012  1,042,947
# 46              The Maze Runner (The Maze Runner, #1)      2009  1,288,566
# 47                          Outlander (Outlander, #1)      1991    942,852
# 48            Frankenstein: The 1818 Text (Paperback)      1818  1,356,508
# 49              Fifty Shades Freed (Fifty Shades, #3)      2012    785,865
#
#    avg_score                       author
# 0       4.32              Suzanne Collins
# 1       4.30              Suzanne Collins
# 2       4.06              Suzanne Collins
# 3       4.16                Veronica Roth
# 4       4.28                  Jane Austen
# 5       4.16                   John Green
# 6       3.99                Veronica Roth
# 7       4.48                 J.K. Rowling
# 8       3.66                   E.L. James
# 9       4.44           George R.R. Martin
# 10      4.11                Gillian Flynn
# 11      4.12              Margaret Atwood
# 12      4.08              Cassandra Clare
# 13      4.11                  Oscar Wilde
# 14      4.19                Sarah J. Maas
# 15      4.43                 J.K. Rowling
# 16      4.10                   Kiera Cass
# 17      4.01                  Bram Stoker
# 18      4.58                 J.K. Rowling
# 19      3.96                Leigh Bardugo
# 20      4.19                Sarah J. Maas
# 21      4.57                 J.K. Rowling
# 22      3.61                Veronica Roth
# 23      4.41                    Andy Weir
# 24      4.19                George Orwell
# 25      4.62                 J.K. Rowling
# 26      4.14             Charlotte Brontë
# 27      4.38                 Markus Zusak
# 28      4.03             Erin Morgenstern
# 29      3.83                   E.L. James
# 30      4.50                 J.K. Rowling
# 31      4.22              Stephen Chbosky
# 32      4.28                 Rick Riordan
# 33      3.93          F. Scott Fitzgerald
# 34      3.75                  E. Lockhart
# 35      4.13                Marissa Meyer
# 36      4.57                 J.K. Rowling
# 37      3.95                Paula Hawkins
# 38      4.28                 Elle Kennedy
# 39      4.24                 Ernest Cline
# 40      3.99               Rainbow Rowell
# 41      4.12            Louisa May Alcott
# 42      4.41           George R.R. Martin
# 43      3.91                 Ransom Riggs
# 44      4.18              Casey McQuiston
# 45      3.98               Rainbow Rowell
# 46      4.04                James Dashner
# 47      4.24               Diana Gabaldon
# 48      3.84  Mary Wollstonecraft Shelley
# 49      3.84                   E.L. James
