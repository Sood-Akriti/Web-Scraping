# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Edge("C:/Users/Anchal/Desktop/msedgedriver.exe")
# Out:
# C:\Users\Anchal\AppData\Local\Temp/ipykernel_13704/3453542444.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge("C:/Users/Anchal/Desktop/msedgedriver.exe")

# %%
names=[]
years=[]
metascores=[]
imdb_ratings=[]
votes=[]
driver.get("https://www.imdb.com/search/title?release_date=2017&sort=num_votes,desc&page=1")

# %%
content = driver.page_source
soup = BeautifulSoup(content)
movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
# Extract data from individual movie container
for container in movie_containers:
# If the movie has Metascore, then extract:
    if container.find('div', class_ = 'ratings-metascore') is not None:
        name = container.h3.a.text
        names.append(name)
        year = container.h3.find('span', class_ = 'lister-item-year').text
        years.append(year)
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)
        m_score = container.find('span', class_ = 'metascore').text
        metascores.append(int(m_score))
        vote = container.find('span', attrs = {'name':'nv'})['data-value']
        votes.append(int(vote))

# %%
import pandas as pd
test_df = pd.DataFrame({'movie': names,
'year': years,
'imdb': imdb_ratings,
'metascore': metascores,
'votes': votes
})
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   movie      41 non-null     object
#  1   year       41 non-null     object
#  2   imdb       41 non-null     float64
#  3   metascore  41 non-null     int64
#  4   votes      41 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.7+ KB
# None
#                                                movie        year  imdb  \
# 0                                              Logan      (2017)   8.1
# 1                                     Thor: Ragnarok      (2017)   7.9
# 2                     Guardians of the Galaxy Vol. 2      (2017)   7.6
# 3                                       Wonder Woman      (2017)   7.4
# 4                                            Dunkirk      (2017)   7.8
# 5                             Spider-Man: Homecoming      (2017)   7.4
# 6            Star Wars: Episode VIII - The Last Jedi      (2017)   6.9
# 7                                            Get Out  (I) (2017)   7.7
# 8                                  Blade Runner 2049      (2017)   8.0
# 9                                                 It  (I) (2017)   7.3
# 10                                       Baby Driver      (2017)   7.6
# 11         Three Billboards Outside Ebbing, Missouri      (2017)   8.1
# 12                                              Coco  (I) (2017)   8.4
# 13                                    Justice League      (2017)   6.1
# 14                              John Wick: Chapter 2      (2017)   7.4
# 15                                The Shape of Water      (2017)   7.3
# 16                    Jumanji: Welcome to the Jungle      (2017)   6.9
# 17                       Kingsman: The Golden Circle      (2017)   6.7
# 18                                Kong: Skull Island      (2017)   6.6
# 19  Pirates of the Caribbean: Dead Men Tell No Tales      (2017)   6.5
# 20                              Beauty and the Beast  (I) (2017)   7.1
# 21                                         Lady Bird      (2017)   7.4
# 22                                   Alien: Covenant      (2017)   6.4
# 23                              The Greatest Showman      (2017)   7.5
# 24                              Call Me by Your Name      (2017)   7.8
# 25                    War for the Planet of the Apes      (2017)   7.4
# 26                      Murder on the Orient Express      (2017)   6.5
# 27                                        Wind River      (2017)   7.7
# 28                           The Fate of the Furious      (2017)   6.6
# 29                            The Hitman's Bodyguard      (2017)   6.9
# 30                                              Life  (I) (2017)   6.6
# 31                                           Mother!      (2017)   6.6
# 32                  King Arthur: Legend of the Sword      (2017)   6.7
# 33                                Ghost in the Shell      (2017)   6.3
# 34                                          I, Tonya      (2017)   7.5
# 35                                      Darkest Hour      (2017)   7.4
# 36                                     Atomic Blonde      (2017)   6.7
# 37                                            Bright  (I) (2017)   6.3
# 38                                         The Mummy      (2017)   5.4
# 39                                          Baywatch      (2017)   5.5
# 40       Valerian and the City of a Thousand Planets      (2017)   6.4
#
#     metascore   votes
# 0          77  736506
# 1          74  708538
# 2          67  657227
# 3          76  642245
# 4          94  637393
# 5          73  634401
# 6          84  617186
# 7          85  566574
# 8          81  546385
# 9          69  521896
# 10         86  517443
# 11         88  493393
# 12         81  483244
# 13         45  444759
# 14         75  417853
# 15         87  411466
# 16         58  368629
# 17         44  320074
# 18         62  313084
# 19         39  303246
# 20         65  302978
# 21         93  281296
# 22         65  276426
# 23         48  274335
# 24         93  261250
# 25         82  251909
# 26         52  251123
# 27         73  245390
# 28         56  228315
# 29         47  227291
# 30         54  226594
# 31         75  219471
# 32         41  213911
# 33         52  212715
# 34         77  210289
# 35         75  197379
# 36         63  190829
# 37         29  186531
# 38         34  185177
# 39         37  183472
# 40         51  179053
